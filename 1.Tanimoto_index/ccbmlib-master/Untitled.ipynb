# %%
#!pip install kora

import kora.install.rdkit
import json  # lets us work with the json format
import requests  # allows Python to make web requests
import pandas as pd # analysis of tabular data
import numpy as np # numerical library
import matplotlib.pyplot as plt # plotting
import rdkit.Chem.AllChem as AllChem # rdkit. chemoinformatics
import rdkit.Chem as Chem
from rdkit.Chem import Draw
from rdkit.Chem import Descriptors
from ipywidgets import interact # widgets
import ipywidgets as widgets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-ee0aa1c2a7ba> in <module>
#       7 import numpy as np # numerical library
#       8 import matplotlib.pyplot as plt # plotting
# ----> 9 import rdkit.Chem.AllChem as AllChem # rdkit. chemoinformatics
#      10 import rdkit.Chem as Chem
#      11 from rdkit.Chem import Draw
#
# ModuleNotFoundError: No module named 'rdkit'

# %%
conda create -c conda-forge -n my-rdkit-env rdkit
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.
